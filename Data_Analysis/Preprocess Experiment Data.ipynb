# %% [markdown]
# # Data Preprocessing Script
#
# The purpose of this script is to decompose the raw dataframe collected from the experiment into dataframes that are suitable for further analysis. Tasks conducted include:
# - Break large data frame into smaller chunks corresponding to different experiment run
# - Drop unnecessary columns
# - Unstack the performance metrics column
# - Save new dataframes as CSV for further processing

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns  # visualization tool
import os

# %%
def extract_from_raw(path_raw_data, path_export_datadir, multi_indexes):
    df = pd.read_csv(path_raw_data)
    df.info()
    df.head()
    # Remove unused columns
    df = df.drop(["name", "job", "__name__"], axis = 1)
    # Find cutoff points between experiments
    cutoffs = list(df[df['time'] == "time"].index)
    cutoffs.insert(0,0)
    cutoffs.append(len(df.index))
    cutoffs
    # Find the deltas between cutoff points
    deltas = [cutoffs[i] - cutoffs[i-1] for i in range(1, len(cutoffs))]
    deltas
    # Loop through repetitions, generate dataframes for each
    for i in range(1, len(cutoffs)):
        if i == 1:
            sub_df = df[cutoffs[i-1]:cutoffs[i]]
        else:
            sub_df = df[cutoffs[i-1]+1:cutoffs[i]]
        # Break the data frame into smaller frames corresponding to instances
        instance_dfs = []
        print('{}{}'.format(i, sub_df["instance"].unique()))
        for instance in sub_df["instance"].unique():
            temp_df = sub_df[sub_df["instance"] == instance].drop("instance", axis = 1)
            # Drop the port name
            temp_df.instance_name = instance.split(":")[0]
            instance_dfs.append(temp_df)
        # Generate unstacked data frame containing system metrics and export to CSV
        for instance_df in instance_dfs:
            if len(multi_indexes) > 1:
                # Generate multi-index
                tuples = list(zip(*[instance_df[index] for index in multi_indexes]))
                index = pd.MultiIndex.from_tuples(tuples, names=multi_indexes)
                # Generate multi-indexed series
                s = pd.Series(list(instance_df["value"]), index = index)
                # Unstack
                unstacked = s.unstack()
                # Write to CSV
                unstacked.to_csv('{}{}_{}.csv'.format(path_export_datadir, i-1, instance_df.instance_name))
            else:
                instance_df.to_csv('{}{}_{}.csv'.format(path_export_datadir, i-1, instance_df.instance_name))

# %%
# Define paths
arrs = ["11", "21", "12"]
subjects = ["1", "2", "3", "4"]
measurements = [
    "node_cpu_seconds_total_data",
    "node_disk_read_bytes_total_data",
    "node_disk_written_bytes_total_data",
    "node_filesystem_free_bytes_data",
    "node_filesystem_size_bytes_data",
    "node_memory_MemAvailable_bytes_data",
    "node_memory_MemTotal_bytes_data",
    "node_network_receive_bytes_total_data",
    "node_network_transmit_bytes_total_data",
    "pijuice_battery_current_data",
    "pijuice_battery_level_data",
    "pijuice_battery_temperature_data",
    "pijuice_battery_voltage_data",
    "pijuice_io_current_data",
    "pijuice_io_voltage_data"
]
multi_indexes_list = [
    ["time", "cpu", "mode"],
    ["time", "device"],
    ["time", "device"],
    ["time", "mountpoint"],
    ["time", "mountpoint"],
    ["time"],
    ["time"],
    ["time", "device"],
    ["time", "device"],
    ["time"],
    ["time"],
    ["time"],
    ["time"],
    ["time"],
    ["time"]    
]

# path_raw_data = "../Raw_Data/Physical-Arrangement-{}/SUB-{}/csv_data/{}/mainflux-influxdb_phy{}_sub{}.csv".format(arr, subject, measurement,arr, subject)
# path_export_datadir = "../Processed_Data/Physical-Arrangement-{}/SUB-{}/{}/".format(arr, subject, measurement)

# %%
for arr in arrs:
    for subject in subjects:
        for i in range(len(measurements)):
            measurement = measurements[i]
            multi_indexes = multi_indexes_list[i]
            path_raw_data = "../Raw_Data/Physical-Arrangement-{}/SUB-{}/csv_data/{}/mainflux-influxdb_phy{}_sub{}.csv".format(arr, subject, measurement,arr, subject)
            path_export_datadir = "../Processed_Data/Physical-Arrangement-{}/SUB-{}/{}/".format(arr, subject, measurement)
            os.makedirs(path_export_datadir)
            print("Processing: {}".format(path_export_datadir))
            extract_from_raw(path_raw_data, path_export_datadir, multi_indexes)
# Out:
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/node_cpu_seconds_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33548 entries, 0 to 33547
# Data columns (total 8 columns):
# time        33548 non-null object
# __name__    33548 non-null object
# cpu         33548 non-null object
# instance    33548 non-null object
# job         33548 non-null object
# mode        33548 non-null object
# name        33548 non-null object
# value       33548 non-null object
# dtypes: object(8)
# memory usage: 2.0+ MB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway2:9100' 'gateway1:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway1:9100' 'gateway2:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/node_disk_read_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3156 entries, 0 to 3155
# Data columns (total 7 columns):
# time        3156 non-null object
# __name__    3156 non-null object
# device      3156 non-null object
# instance    3156 non-null object
# job         3156 non-null object
# name        3156 non-null object
# value       3156 non-null object
# dtypes: object(7)
# memory usage: 172.7+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway2:9100' 'gateway1:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway1:9100' 'gateway2:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/node_disk_written_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3156 entries, 0 to 3155
# Data columns (total 7 columns):
# time        3156 non-null object
# __name__    3156 non-null object
# device      3156 non-null object
# instance    3156 non-null object
# job         3156 non-null object
# name        3156 non-null object
# value       3156 non-null object
# dtypes: object(7)
# memory usage: 172.7+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway2:9100' 'gateway1:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway1:9100' 'gateway2:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/node_filesystem_free_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4396 entries, 0 to 4395
# Data columns (total 9 columns):
# time          4396 non-null object
# __name__      4396 non-null object
# device        4396 non-null object
# fstype        4396 non-null object
# instance      4396 non-null object
# job           4396 non-null object
# mountpoint    4396 non-null object
# name          4396 non-null object
# value         4396 non-null object
# dtypes: object(9)
# memory usage: 309.2+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway2:9100' 'gateway1:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway1:9100' 'gateway2:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/node_filesystem_size_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4396 entries, 0 to 4395
# Data columns (total 9 columns):
# time          4396 non-null object
# __name__      4396 non-null object
# device        4396 non-null object
# fstype        4396 non-null object
# instance      4396 non-null object
# job           4396 non-null object
# mountpoint    4396 non-null object
# name          4396 non-null object
# value         4396 non-null object
# dtypes: object(9)
# memory usage: 309.2+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway2:9100' 'gateway1:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway1:9100' 'gateway2:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/node_memory_MemAvailable_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 6 columns):
# time        1060 non-null object
# __name__    1060 non-null object
# instance    1060 non-null object
# job         1060 non-null object
# name        1060 non-null object
# value       1060 non-null object
# dtypes: object(6)
# memory usage: 49.8+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway2:9100' 'gateway1:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway1:9100' 'gateway2:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/node_memory_MemTotal_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 6 columns):
# time        1060 non-null object
# __name__    1060 non-null object
# instance    1060 non-null object
# job         1060 non-null object
# name        1060 non-null object
# value       1060 non-null object
# dtypes: object(6)
# memory usage: 49.8+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway2:9100' 'gateway1:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway1:9100' 'gateway2:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/node_network_receive_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6300 entries, 0 to 6299
# Data columns (total 7 columns):
# time        6300 non-null object
# __name__    6300 non-null object
# device      6300 non-null object
# instance    6300 non-null object
# job         6300 non-null object
# name        6300 non-null object
# value       6300 non-null object
# dtypes: object(7)
# memory usage: 344.6+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway2:9100' 'gateway1:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway1:9100' 'gateway2:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/node_network_transmit_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6300 entries, 0 to 6299
# Data columns (total 7 columns):
# time        6300 non-null object
# __name__    6300 non-null object
# device      6300 non-null object
# instance    6300 non-null object
# job         6300 non-null object
# name        6300 non-null object
# value       6300 non-null object
# dtypes: object(7)
# memory usage: 344.6+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway2:9100' 'gateway1:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway1:9100' 'gateway2:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/pijuice_battery_current_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 6 columns):
# time        1104 non-null object
# __name__    1104 non-null object
# instance    1104 non-null object
# job         1104 non-null object
# name        1104 non-null object
# value       1104 non-null object
# dtypes: object(6)
# memory usage: 51.8+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway1:8080' 'gateway2:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway2:8080' 'gateway1:8080']
# 11['gateway2:8080' 'gateway1:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/pijuice_battery_level_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 6 columns):
# time        1104 non-null object
# __name__    1104 non-null object
# instance    1104 non-null object
# job         1104 non-null object
# name        1104 non-null object
# value       1104 non-null object
# dtypes: object(6)
# memory usage: 51.8+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway1:8080' 'gateway2:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway2:8080' 'gateway1:8080']
# 11['gateway2:8080' 'gateway1:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/pijuice_battery_temperature_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 6 columns):
# time        1104 non-null object
# __name__    1104 non-null object
# instance    1104 non-null object
# job         1104 non-null object
# name        1104 non-null object
# value       1104 non-null object
# dtypes: object(6)
# memory usage: 51.8+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway1:8080' 'gateway2:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway2:8080' 'gateway1:8080']
# 11['gateway2:8080' 'gateway1:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/pijuice_battery_voltage_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 6 columns):
# time        1104 non-null object
# __name__    1104 non-null object
# instance    1104 non-null object
# job         1104 non-null object
# name        1104 non-null object
# value       1104 non-null object
# dtypes: object(6)
# memory usage: 51.8+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway1:8080' 'gateway2:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway2:8080' 'gateway1:8080']
# 11['gateway2:8080' 'gateway1:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/pijuice_io_current_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 6 columns):
# time        1104 non-null object
# __name__    1104 non-null object
# instance    1104 non-null object
# job         1104 non-null object
# name        1104 non-null object
# value       1104 non-null object
# dtypes: object(6)
# memory usage: 51.8+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway1:8080' 'gateway2:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway2:8080' 'gateway1:8080']
# 11['gateway2:8080' 'gateway1:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-1/pijuice_io_voltage_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1104 entries, 0 to 1103
# Data columns (total 6 columns):
# time        1104 non-null object
# __name__    1104 non-null object
# instance    1104 non-null object
# job         1104 non-null object
# name        1104 non-null object
# value       1104 non-null object
# dtypes: object(6)
# memory usage: 51.8+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway1:8080' 'gateway2:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway2:8080' 'gateway1:8080']
# 11['gateway2:8080' 'gateway1:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/node_cpu_seconds_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33548 entries, 0 to 33547
# Data columns (total 8 columns):
# time        33548 non-null object
# __name__    33548 non-null object
# cpu         33548 non-null object
# instance    33548 non-null object
# job         33548 non-null object
# mode        33548 non-null object
# name        33548 non-null object
# value       33548 non-null object
# dtypes: object(8)
# memory usage: 2.0+ MB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway1:9100' 'gateway2:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway2:9100' 'gateway1:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/node_disk_read_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3156 entries, 0 to 3155
# Data columns (total 7 columns):
# time        3156 non-null object
# __name__    3156 non-null object
# device      3156 non-null object
# instance    3156 non-null object
# job         3156 non-null object
# name        3156 non-null object
# value       3156 non-null object
# dtypes: object(7)
# memory usage: 172.7+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway1:9100' 'gateway2:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway2:9100' 'gateway1:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/node_disk_written_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3156 entries, 0 to 3155
# Data columns (total 7 columns):
# time        3156 non-null object
# __name__    3156 non-null object
# device      3156 non-null object
# instance    3156 non-null object
# job         3156 non-null object
# name        3156 non-null object
# value       3156 non-null object
# dtypes: object(7)
# memory usage: 172.7+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway1:9100' 'gateway2:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway2:9100' 'gateway1:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/node_filesystem_free_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5252 entries, 0 to 5251
# Data columns (total 9 columns):
# time          5252 non-null object
# __name__      5252 non-null object
# device        5252 non-null object
# fstype        5252 non-null object
# instance      5252 non-null object
# job           5252 non-null object
# mountpoint    5252 non-null object
# name          5252 non-null object
# value         5252 non-null object
# dtypes: object(9)
# memory usage: 369.4+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway1:9100' 'gateway2:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway2:9100' 'gateway1:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/node_filesystem_size_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5252 entries, 0 to 5251
# Data columns (total 9 columns):
# time          5252 non-null object
# __name__      5252 non-null object
# device        5252 non-null object
# fstype        5252 non-null object
# instance      5252 non-null object
# job           5252 non-null object
# mountpoint    5252 non-null object
# name          5252 non-null object
# value         5252 non-null object
# dtypes: object(9)
# memory usage: 369.4+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway1:9100' 'gateway2:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway2:9100' 'gateway1:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/node_memory_MemAvailable_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 6 columns):
# time        1060 non-null object
# __name__    1060 non-null object
# instance    1060 non-null object
# job         1060 non-null object
# name        1060 non-null object
# value       1060 non-null object
# dtypes: object(6)
# memory usage: 49.8+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway1:9100' 'gateway2:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway2:9100' 'gateway1:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/node_memory_MemTotal_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1060 entries, 0 to 1059
# Data columns (total 6 columns):
# time        1060 non-null object
# __name__    1060 non-null object
# instance    1060 non-null object
# job         1060 non-null object
# name        1060 non-null object
# value       1060 non-null object
# dtypes: object(6)
# memory usage: 49.8+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway1:9100' 'gateway2:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway2:9100' 'gateway1:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/node_network_receive_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7348 entries, 0 to 7347
# Data columns (total 7 columns):
# time        7348 non-null object
# __name__    7348 non-null object
# device      7348 non-null object
# instance    7348 non-null object
# job         7348 non-null object
# name        7348 non-null object
# value       7348 non-null object
# dtypes: object(7)
# memory usage: 401.9+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway1:9100' 'gateway2:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway2:9100' 'gateway1:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/node_network_transmit_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7348 entries, 0 to 7347
# Data columns (total 7 columns):
# time        7348 non-null object
# __name__    7348 non-null object
# device      7348 non-null object
# instance    7348 non-null object
# job         7348 non-null object
# name        7348 non-null object
# value       7348 non-null object
# dtypes: object(7)
# memory usage: 401.9+ KB
# 1['gateway2:9100' 'gateway1:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway1:9100' 'gateway2:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway1:9100' 'gateway2:9100']
# 6['gateway2:9100' 'gateway1:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# 13['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/pijuice_battery_current_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1099 entries, 0 to 1098
# Data columns (total 6 columns):
# time        1099 non-null object
# __name__    1099 non-null object
# instance    1099 non-null object
# job         1099 non-null object
# name        1099 non-null object
# value       1099 non-null object
# dtypes: object(6)
# memory usage: 51.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway1:8080' 'gateway2:8080']
# 3['gateway1:8080' 'gateway2:8080']
# 4['gateway1:8080' 'gateway2:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway2:8080' 'gateway1:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/pijuice_battery_level_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1099 entries, 0 to 1098
# Data columns (total 6 columns):
# time        1099 non-null object
# __name__    1099 non-null object
# instance    1099 non-null object
# job         1099 non-null object
# name        1099 non-null object
# value       1099 non-null object
# dtypes: object(6)
# memory usage: 51.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway1:8080' 'gateway2:8080']
# 3['gateway1:8080' 'gateway2:8080']
# 4['gateway1:8080' 'gateway2:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway2:8080' 'gateway1:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/pijuice_battery_temperature_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1099 entries, 0 to 1098
# Data columns (total 6 columns):
# time        1099 non-null object
# __name__    1099 non-null object
# instance    1099 non-null object
# job         1099 non-null object
# name        1099 non-null object
# value       1099 non-null object
# dtypes: object(6)
# memory usage: 51.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway1:8080' 'gateway2:8080']
# 3['gateway1:8080' 'gateway2:8080']
# 4['gateway1:8080' 'gateway2:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway2:8080' 'gateway1:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/pijuice_battery_voltage_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1099 entries, 0 to 1098
# Data columns (total 6 columns):
# time        1099 non-null object
# __name__    1099 non-null object
# instance    1099 non-null object
# job         1099 non-null object
# name        1099 non-null object
# value       1099 non-null object
# dtypes: object(6)
# memory usage: 51.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway1:8080' 'gateway2:8080']
# 3['gateway1:8080' 'gateway2:8080']
# 4['gateway1:8080' 'gateway2:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway2:8080' 'gateway1:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/pijuice_io_current_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1099 entries, 0 to 1098
# Data columns (total 6 columns):
# time        1099 non-null object
# __name__    1099 non-null object
# instance    1099 non-null object
# job         1099 non-null object
# name        1099 non-null object
# value       1099 non-null object
# dtypes: object(6)
# memory usage: 51.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway1:8080' 'gateway2:8080']
# 3['gateway1:8080' 'gateway2:8080']
# 4['gateway1:8080' 'gateway2:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway2:8080' 'gateway1:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-2/pijuice_io_voltage_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1099 entries, 0 to 1098
# Data columns (total 6 columns):
# time        1099 non-null object
# __name__    1099 non-null object
# instance    1099 non-null object
# job         1099 non-null object
# name        1099 non-null object
# value       1099 non-null object
# dtypes: object(6)
# memory usage: 51.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway1:8080' 'gateway2:8080']
# 3['gateway1:8080' 'gateway2:8080']
# 4['gateway1:8080' 'gateway2:8080']
# 5['gateway1:8080' 'gateway2:8080']
# 6['gateway2:8080' 'gateway1:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway2:8080' 'gateway1:8080']
# 9['gateway2:8080' 'gateway1:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway2:8080' 'gateway1:8080']
# 13['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/node_cpu_seconds_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 31467 entries, 0 to 31466
# Data columns (total 8 columns):
# time        31467 non-null object
# __name__    31467 non-null object
# cpu         31467 non-null object
# instance    31467 non-null object
# job         31467 non-null object
# mode        31467 non-null object
# name        31467 non-null object
# value       31467 non-null object
# dtypes: object(8)
# memory usage: 1.9+ MB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/node_disk_read_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2960 entries, 0 to 2959
# Data columns (total 7 columns):
# time        2960 non-null object
# __name__    2960 non-null object
# device      2960 non-null object
# instance    2960 non-null object
# job         2960 non-null object
# name        2960 non-null object
# value       2960 non-null object
# dtypes: object(7)
# memory usage: 162.0+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/node_disk_written_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2960 entries, 0 to 2959
# Data columns (total 7 columns):
# time        2960 non-null object
# __name__    2960 non-null object
# device      2960 non-null object
# instance    2960 non-null object
# job         2960 non-null object
# name        2960 non-null object
# value       2960 non-null object
# dtypes: object(7)
# memory usage: 162.0+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/node_filesystem_free_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4926 entries, 0 to 4925
# Data columns (total 9 columns):
# time          4926 non-null object
# __name__      4926 non-null object
# device        4926 non-null object
# fstype        4926 non-null object
# instance      4926 non-null object
# job           4926 non-null object
# mountpoint    4926 non-null object
# name          4926 non-null object
# value         4926 non-null object
# dtypes: object(9)
# memory usage: 346.4+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/node_filesystem_size_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4926 entries, 0 to 4925
# Data columns (total 9 columns):
# time          4926 non-null object
# __name__      4926 non-null object
# device        4926 non-null object
# fstype        4926 non-null object
# instance      4926 non-null object
# job           4926 non-null object
# mountpoint    4926 non-null object
# name          4926 non-null object
# value         4926 non-null object
# dtypes: object(9)
# memory usage: 346.4+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/node_memory_MemAvailable_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994 entries, 0 to 993
# Data columns (total 6 columns):
# time        994 non-null object
# __name__    994 non-null object
# instance    994 non-null object
# job         994 non-null object
# name        994 non-null object
# value       994 non-null object
# dtypes: object(6)
# memory usage: 46.7+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/node_memory_MemTotal_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 994 entries, 0 to 993
# Data columns (total 6 columns):
# time        994 non-null object
# __name__    994 non-null object
# instance    994 non-null object
# job         994 non-null object
# name        994 non-null object
# value       994 non-null object
# dtypes: object(6)
# memory usage: 46.7+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/node_network_receive_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5909 entries, 0 to 5908
# Data columns (total 7 columns):
# time        5909 non-null object
# __name__    5909 non-null object
# device      5909 non-null object
# instance    5909 non-null object
# job         5909 non-null object
# name        5909 non-null object
# value       5909 non-null object
# dtypes: object(7)
# memory usage: 323.2+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/node_network_transmit_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5909 entries, 0 to 5908
# Data columns (total 7 columns):
# time        5909 non-null object
# __name__    5909 non-null object
# device      5909 non-null object
# instance    5909 non-null object
# job         5909 non-null object
# name        5909 non-null object
# value       5909 non-null object
# dtypes: object(7)
# memory usage: 323.2+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway1:9100' 'gateway2:9100']
# 10['gateway1:9100' 'gateway2:9100']
# 11['gateway1:9100' 'gateway2:9100']
# 12['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/pijuice_battery_current_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 6 columns):
# time        1033 non-null object
# __name__    1033 non-null object
# instance    1033 non-null object
# job         1033 non-null object
# name        1033 non-null object
# value       1033 non-null object
# dtypes: object(6)
# memory usage: 48.5+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway2:8080' 'gateway1:8080']
# 6['gateway1:8080' 'gateway2:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway1:8080' 'gateway2:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/pijuice_battery_level_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 6 columns):
# time        1033 non-null object
# __name__    1033 non-null object
# instance    1033 non-null object
# job         1033 non-null object
# name        1033 non-null object
# value       1033 non-null object
# dtypes: object(6)
# memory usage: 48.5+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway2:8080' 'gateway1:8080']
# 6['gateway1:8080' 'gateway2:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway1:8080' 'gateway2:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/pijuice_battery_temperature_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 6 columns):
# time        1033 non-null object
# __name__    1033 non-null object
# instance    1033 non-null object
# job         1033 non-null object
# name        1033 non-null object
# value       1033 non-null object
# dtypes: object(6)
# memory usage: 48.5+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway2:8080' 'gateway1:8080']
# 6['gateway1:8080' 'gateway2:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway1:8080' 'gateway2:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/pijuice_battery_voltage_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 6 columns):
# time        1033 non-null object
# __name__    1033 non-null object
# instance    1033 non-null object
# job         1033 non-null object
# name        1033 non-null object
# value       1033 non-null object
# dtypes: object(6)
# memory usage: 48.5+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway2:8080' 'gateway1:8080']
# 6['gateway1:8080' 'gateway2:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway1:8080' 'gateway2:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/pijuice_io_current_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 6 columns):
# time        1033 non-null object
# __name__    1033 non-null object
# instance    1033 non-null object
# job         1033 non-null object
# name        1033 non-null object
# value       1033 non-null object
# dtypes: object(6)
# memory usage: 48.5+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway2:8080' 'gateway1:8080']
# 6['gateway1:8080' 'gateway2:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway1:8080' 'gateway2:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-3/pijuice_io_voltage_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1033 entries, 0 to 1032
# Data columns (total 6 columns):
# time        1033 non-null object
# __name__    1033 non-null object
# instance    1033 non-null object
# job         1033 non-null object
# name        1033 non-null object
# value       1033 non-null object
# dtypes: object(6)
# memory usage: 48.5+ KB
# 1['gateway2:8080' 'gateway1:8080']
# 2['gateway2:8080' 'gateway1:8080']
# 3['gateway2:8080' 'gateway1:8080']
# 4['gateway2:8080' 'gateway1:8080']
# 5['gateway2:8080' 'gateway1:8080']
# 6['gateway1:8080' 'gateway2:8080']
# 7['gateway2:8080' 'gateway1:8080']
# 8['gateway1:8080' 'gateway2:8080']
# 9['gateway1:8080' 'gateway2:8080']
# 10['gateway1:8080' 'gateway2:8080']
# 11['gateway1:8080' 'gateway2:8080']
# 12['gateway1:8080' 'gateway2:8080']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-4/node_cpu_seconds_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 33644 entries, 0 to 33643
# Data columns (total 8 columns):
# time        33644 non-null object
# __name__    33644 non-null object
# cpu         33644 non-null object
# instance    33644 non-null object
# job         33644 non-null object
# mode        33644 non-null object
# name        33644 non-null object
# value       33644 non-null object
# dtypes: object(8)
# memory usage: 2.1+ MB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway2:9100' 'gateway1:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-4/node_disk_read_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3165 entries, 0 to 3164
# Data columns (total 7 columns):
# time        3165 non-null object
# __name__    3165 non-null object
# device      3165 non-null object
# instance    3165 non-null object
# job         3165 non-null object
# name        3165 non-null object
# value       3165 non-null object
# dtypes: object(7)
# memory usage: 173.2+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway2:9100' 'gateway1:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-4/node_disk_written_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3165 entries, 0 to 3164
# Data columns (total 7 columns):
# time        3165 non-null object
# __name__    3165 non-null object
# device      3165 non-null object
# instance    3165 non-null object
# job         3165 non-null object
# name        3165 non-null object
# value       3165 non-null object
# dtypes: object(7)
# memory usage: 173.2+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway2:9100' 'gateway1:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-4/node_filesystem_free_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5267 entries, 0 to 5266
# Data columns (total 9 columns):
# time          5267 non-null object
# __name__      5267 non-null object
# device        5267 non-null object
# fstype        5267 non-null object
# instance      5267 non-null object
# job           5267 non-null object
# mountpoint    5267 non-null object
# name          5267 non-null object
# value         5267 non-null object
# dtypes: object(9)
# memory usage: 370.4+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway2:9100' 'gateway1:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-4/node_filesystem_size_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5267 entries, 0 to 5266
# Data columns (total 9 columns):
# time          5267 non-null object
# __name__      5267 non-null object
# device        5267 non-null object
# fstype        5267 non-null object
# instance      5267 non-null object
# job           5267 non-null object
# mountpoint    5267 non-null object
# name          5267 non-null object
# value         5267 non-null object
# dtypes: object(9)
# memory usage: 370.4+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway2:9100' 'gateway1:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-4/node_memory_MemAvailable_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1063 entries, 0 to 1062
# Data columns (total 6 columns):
# time        1063 non-null object
# __name__    1063 non-null object
# instance    1063 non-null object
# job         1063 non-null object
# name        1063 non-null object
# value       1063 non-null object
# dtypes: object(6)
# memory usage: 49.9+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway2:9100' 'gateway1:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-4/node_memory_MemTotal_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1063 entries, 0 to 1062
# Data columns (total 6 columns):
# time        1063 non-null object
# __name__    1063 non-null object
# instance    1063 non-null object
# job         1063 non-null object
# name        1063 non-null object
# value       1063 non-null object
# dtypes: object(6)
# memory usage: 49.9+ KB
# 1['gateway1:9100' 'gateway2:9100']
# 2['gateway1:9100' 'gateway2:9100']
# 3['gateway2:9100' 'gateway1:9100']
# 4['gateway2:9100' 'gateway1:9100']
# 5['gateway2:9100' 'gateway1:9100']
# 6['gateway1:9100' 'gateway2:9100']
# 7['gateway2:9100' 'gateway1:9100']
# 8['gateway1:9100' 'gateway2:9100']
# 9['gateway2:9100' 'gateway1:9100']
# 10['gateway2:9100' 'gateway1:9100']
# 11['gateway2:9100' 'gateway1:9100']
# 12['gateway2:9100' 'gateway1:9100']
# 13['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-11/SUB-4/node_network_receive_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7369 entries, 0 to 7368
# Data columns (total 7 columns):
# ...
# time        373 non-null object
# __name__    373 non-null object
# instance    373 non-null object
# job         373 non-null object
# name        373 non-null object
# value       373 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-2/pijuice_io_voltage_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 6 columns):
# time        373 non-null object
# __name__    373 non-null object
# instance    373 non-null object
# job         373 non-null object
# name        373 non-null object
# value       373 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/node_cpu_seconds_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11840 entries, 0 to 11839
# Data columns (total 8 columns):
# time        11840 non-null object
# __name__    11840 non-null object
# cpu         11840 non-null int64
# instance    11840 non-null object
# job         11840 non-null object
# mode        11840 non-null object
# name        11840 non-null object
# value       11840 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 740.1+ KB
# 1['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/node_disk_read_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 7 columns):
# time        1110 non-null object
# __name__    1110 non-null object
# device      1110 non-null object
# instance    1110 non-null object
# job         1110 non-null object
# name        1110 non-null object
# value       1110 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 60.8+ KB
# 1['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/node_disk_written_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 7 columns):
# time        1110 non-null object
# __name__    1110 non-null object
# device      1110 non-null object
# instance    1110 non-null object
# job         1110 non-null object
# name        1110 non-null object
# value       1110 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 60.8+ KB
# 1['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/node_filesystem_free_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 9 columns):
# time          1850 non-null object
# __name__      1850 non-null object
# device        1850 non-null object
# fstype        1850 non-null object
# instance      1850 non-null object
# job           1850 non-null object
# mountpoint    1850 non-null object
# name          1850 non-null object
# value         1850 non-null int64
# dtypes: int64(1), object(8)
# memory usage: 130.2+ KB
# 1['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/node_filesystem_size_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 9 columns):
# time          1850 non-null object
# __name__      1850 non-null object
# device        1850 non-null object
# fstype        1850 non-null object
# instance      1850 non-null object
# job           1850 non-null object
# mountpoint    1850 non-null object
# name          1850 non-null object
# value         1850 non-null int64
# dtypes: int64(1), object(8)
# memory usage: 130.2+ KB
# 1['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/node_memory_MemAvailable_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 6 columns):
# time        370 non-null object
# __name__    370 non-null object
# instance    370 non-null object
# job         370 non-null object
# name        370 non-null object
# value       370 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.4+ KB
# 1['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/node_memory_MemTotal_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 6 columns):
# time        370 non-null object
# __name__    370 non-null object
# instance    370 non-null object
# job         370 non-null object
# name        370 non-null object
# value       370 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.4+ KB
# 1['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/node_network_receive_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2220 entries, 0 to 2219
# Data columns (total 7 columns):
# time        2220 non-null object
# __name__    2220 non-null object
# device      2220 non-null object
# instance    2220 non-null object
# job         2220 non-null object
# name        2220 non-null object
# value       2220 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 121.5+ KB
# 1['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/node_network_transmit_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2220 entries, 0 to 2219
# Data columns (total 7 columns):
# time        2220 non-null object
# __name__    2220 non-null object
# device      2220 non-null object
# instance    2220 non-null object
# job         2220 non-null object
# name        2220 non-null object
# value       2220 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 121.5+ KB
# 1['gateway2:9100' 'gateway1:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/pijuice_battery_current_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 6 columns):
# time        373 non-null object
# __name__    373 non-null object
# instance    373 non-null object
# job         373 non-null object
# name        373 non-null object
# value       373 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/pijuice_battery_level_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 6 columns):
# time        373 non-null object
# __name__    373 non-null object
# instance    373 non-null object
# job         373 non-null object
# name        373 non-null object
# value       373 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/pijuice_battery_temperature_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 6 columns):
# time        373 non-null object
# __name__    373 non-null object
# instance    373 non-null object
# job         373 non-null object
# name        373 non-null object
# value       373 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/pijuice_battery_voltage_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 6 columns):
# time        373 non-null object
# __name__    373 non-null object
# instance    373 non-null object
# job         373 non-null object
# name        373 non-null object
# value       373 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/pijuice_io_current_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 6 columns):
# time        373 non-null object
# __name__    373 non-null object
# instance    373 non-null object
# job         373 non-null object
# name        373 non-null object
# value       373 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-3/pijuice_io_voltage_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 373 entries, 0 to 372
# Data columns (total 6 columns):
# time        373 non-null object
# __name__    373 non-null object
# instance    373 non-null object
# job         373 non-null object
# name        373 non-null object
# value       373 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/node_cpu_seconds_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11840 entries, 0 to 11839
# Data columns (total 8 columns):
# time        11840 non-null object
# __name__    11840 non-null object
# cpu         11840 non-null int64
# instance    11840 non-null object
# job         11840 non-null object
# mode        11840 non-null object
# name        11840 non-null object
# value       11840 non-null float64
# dtypes: float64(1), int64(1), object(6)
# memory usage: 740.1+ KB
# 1['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/node_disk_read_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 7 columns):
# time        1110 non-null object
# __name__    1110 non-null object
# device      1110 non-null object
# instance    1110 non-null object
# job         1110 non-null object
# name        1110 non-null object
# value       1110 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 60.8+ KB
# 1['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/node_disk_written_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1110 entries, 0 to 1109
# Data columns (total 7 columns):
# time        1110 non-null object
# __name__    1110 non-null object
# device      1110 non-null object
# instance    1110 non-null object
# job         1110 non-null object
# name        1110 non-null object
# value       1110 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 60.8+ KB
# 1['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/node_filesystem_free_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 9 columns):
# time          1850 non-null object
# __name__      1850 non-null object
# device        1850 non-null object
# fstype        1850 non-null object
# instance      1850 non-null object
# job           1850 non-null object
# mountpoint    1850 non-null object
# name          1850 non-null object
# value         1850 non-null int64
# dtypes: int64(1), object(8)
# memory usage: 130.2+ KB
# 1['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/node_filesystem_size_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1850 entries, 0 to 1849
# Data columns (total 9 columns):
# time          1850 non-null object
# __name__      1850 non-null object
# device        1850 non-null object
# fstype        1850 non-null object
# instance      1850 non-null object
# job           1850 non-null object
# mountpoint    1850 non-null object
# name          1850 non-null object
# value         1850 non-null int64
# dtypes: int64(1), object(8)
# memory usage: 130.2+ KB
# 1['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/node_memory_MemAvailable_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 6 columns):
# time        370 non-null object
# __name__    370 non-null object
# instance    370 non-null object
# job         370 non-null object
# name        370 non-null object
# value       370 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.4+ KB
# 1['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/node_memory_MemTotal_bytes_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 370 entries, 0 to 369
# Data columns (total 6 columns):
# time        370 non-null object
# __name__    370 non-null object
# instance    370 non-null object
# job         370 non-null object
# name        370 non-null object
# value       370 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.4+ KB
# 1['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/node_network_receive_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2590 entries, 0 to 2589
# Data columns (total 7 columns):
# time        2590 non-null object
# __name__    2590 non-null object
# device      2590 non-null object
# instance    2590 non-null object
# job         2590 non-null object
# name        2590 non-null object
# value       2590 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 141.7+ KB
# 1['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/node_network_transmit_bytes_total_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2590 entries, 0 to 2589
# Data columns (total 7 columns):
# time        2590 non-null object
# __name__    2590 non-null object
# device      2590 non-null object
# instance    2590 non-null object
# job         2590 non-null object
# name        2590 non-null object
# value       2590 non-null int64
# dtypes: int64(1), object(6)
# memory usage: 141.7+ KB
# 1['gateway1:9100' 'gateway2:9100']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/pijuice_battery_current_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 6 columns):
# time        374 non-null object
# __name__    374 non-null object
# instance    374 non-null object
# job         374 non-null object
# name        374 non-null object
# value       374 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/pijuice_battery_level_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 6 columns):
# time        374 non-null object
# __name__    374 non-null object
# instance    374 non-null object
# job         374 non-null object
# name        374 non-null object
# value       374 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/pijuice_battery_temperature_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 6 columns):
# time        374 non-null object
# __name__    374 non-null object
# instance    374 non-null object
# job         374 non-null object
# name        374 non-null object
# value       374 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/pijuice_battery_voltage_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 6 columns):
# time        374 non-null object
# __name__    374 non-null object
# instance    374 non-null object
# job         374 non-null object
# name        374 non-null object
# value       374 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/pijuice_io_current_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 6 columns):
# time        374 non-null object
# __name__    374 non-null object
# instance    374 non-null object
# job         374 non-null object
# name        374 non-null object
# value       374 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']
# Processing: ../Processed_Data/Physical-Arrangement-12/SUB-4/pijuice_io_voltage_data/
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 6 columns):
# time        374 non-null object
# __name__    374 non-null object
# instance    374 non-null object
# job         374 non-null object
# name        374 non-null object
# value       374 non-null int64
# dtypes: int64(1), object(5)
# memory usage: 17.6+ KB
# 1['gateway2:8080' 'gateway1:8080']

# %%
## These code are for testing and development


# Define paths
arr = "11"
subject = "1"
measurement = "node_filesystem_free_bytes_data"
path_raw_data = "../Raw_Data/Physical-Arrangement-{}/SUB-{}/csv_data/{}/mainflux-influxdb_phy{}_sub{}.csv".format(arr, subject, measurement,arr, subject)
path_export_datadir = "../Processed_Data/Physical-Arrangement-{}/SUB-{}/{}/".format(arr, subject, measurement)
multi_indexes = ["time", "mountpoint"]
os.makedirs(path_export_datadir)
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-597-4d3e13c6a114> in <module>
#       6 path_export_datadir = "../Processed_Data/Physical-Arrangement-{}/SUB-{}/{}/".format(arr, subject, measurement)
#       7 multi_indexes = ["time", "mountpoint"]
# ----> 8 os.makedirs(path_export_datadir)
#
# /anaconda3/lib/python3.7/os.py in makedirs(name, mode, exist_ok)
#     219             return
#     220     try:
# --> 221         mkdir(name, mode)
#     222     except OSError:
#     223         # Cannot rely on checking for EEXIST, since the operating system
#
# FileExistsError: [Errno 17] File exists: '../Processed_Data/Physical-Arrangement-11/SUB-1/node_filesystem_free_bytes_data/'

# %%
df = pd.read_csv(path_raw_data)
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4396 entries, 0 to 4395
# Data columns (total 9 columns):
# time          4396 non-null object
# __name__      4396 non-null object
# device        4396 non-null object
# fstype        4396 non-null object
# instance      4396 non-null object
# job           4396 non-null object
# mountpoint    4396 non-null object
# name          4396 non-null object
# value         4396 non-null object
# dtypes: object(9)
# memory usage: 309.2+ KB

# %%
df.head()
# Out:
#                        time                    __name__          device  \
# 0  2020-02-24T12:29:22.444Z  node_filesystem_free_bytes  /dev/mmcblk0p1
# 1  2020-02-24T12:29:22.444Z  node_filesystem_free_bytes       /dev/root
# 2  2020-02-24T12:29:22.444Z  node_filesystem_free_bytes           tmpfs
# 3  2020-02-24T12:29:22.444Z  node_filesystem_free_bytes           tmpfs
# 4  2020-02-24T12:29:22.444Z  node_filesystem_free_bytes           tmpfs
#
#   fstype       instance         job      mountpoint          name        value
# 0   vfat  gateway2:9100  prometheus           /boot  gateway2_cpu    208601088
# 1   ext4  gateway2:9100  prometheus               /  gateway2_cpu  12046438400
# 2  tmpfs  gateway2:9100  prometheus            /run  gateway2_cpu    468467712
# 3  tmpfs  gateway2:9100  prometheus       /run/lock  gateway2_cpu      5238784
# 4  tmpfs  gateway2:9100  prometheus  /run/user/1000  gateway2_cpu    101675008

# %%
# Remove unused columns
df = df.drop(["name", "job", "__name__"], axis = 1)

# %%
# Find cutoff points between experiments
cutoffs = list(df[df['time'] == "time"].index)
cutoffs.insert(0,0)
cutoffs.append(len(df.index))
cutoffs
# Out:
# [0, 511, 799, 1315, 1831, 2114, 2398, 2681, 2970, 3253, 3537, 3825, 4113, 4396]

# %%
# Find the deltas between cutoff points
deltas = [cutoffs[i] - cutoffs[i-1] for i in range(1, len(cutoffs))]
deltas
# Out:
# [511, 288, 516, 516, 283, 284, 283, 289, 283, 284, 288, 288, 283]

# %%
# Loop through repetitions, generate dataframes for each
for i in range(1, len(cutoffs)):
    if i == 1:
        sub_df = df[cutoffs[i-1]:cutoffs[i]]
    else:
        sub_df = df[cutoffs[i-1]+1:cutoffs[i]]
    # Break the data frame into smaller frames corresponding to instances
    instance_dfs = []
    print('{}{}'.format(i, sub_df["instance"].unique()))
    for instance in sub_df["instance"].unique():
        temp_df = sub_df[sub_df["instance"] == instance].drop("instance", axis = 1)
        temp_df.instance_name = instance
        instance_dfs.append(temp_df)
    # Generate unstacked data frame containing system metrics and export to CSV
    for instance_df in instance_dfs:
#         print(instance_df.head(20))
        if len(multi_indexes) > 1:
            # Generate multi-index
            tuples = list(zip(*[instance_df[index] for index in multi_indexes]))
            index = pd.MultiIndex.from_tuples(tuples, names=multi_indexes)
            # Generate multi-indexed series
            s = pd.Series(list(instance_df["value"]), index = index)
            print(s.head(20))
            # Unstack
            unstacked = s.unstack()
            print(unstacked.head())
            # Write to CSV
#             unstacked.to_csv('{}{}_{}.csv'.format(path_export_datadir, i-1, instance_df.instance_name))
        else:
            instance_df.to_csv('{}{}_{}.csv'.format(path_export_datadir, i-1, instance_df.instance_name))
# Out:
# 1['gateway2:9100' 'gateway1:9100']
# time                      mountpoint
# 2020-02-24T12:29:22.444Z  /boot               208601088
#                           /                 12046438400
#                           /run                468467712
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T12
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T14:14:42.444Z  /boot               208601088
#                           /                 12046757888
#                           /run                461864960
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T14:14:52.444Z  /boot               208601088
#                           /                 12046757888
#                           /run                461864960
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T14:15:02.444Z  /boot               208601088
#                           /                 12046757888
#                           /run                461864960
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# dtype: object
# mountpoint                          /      /boot       /run /run/lock  \
# time
# 2020-02-24T14:14:32.444Z  12046761984  208601088  461869056   5238784
# 2020-02-24T14:14:42.444Z  12046757888  208601088  461864960   5238784
# 2020-02-24T14:14:52.444Z  12046757888  208601088  461864960   5238784
# 2020-02-24T14:15:02.444Z  12046757888  208601088  461864960   5238784
# 2020-02-24T14:15:12.444Z  12046757888  208601088  461864960   5238784
#
# mountpoint               /run/user/1000
# time
# 2020-02-24T14:14:32.444Z      101675008
# 2020-02-24T14:14:42.444Z      101675008
# 2020-02-24T14:14:52.444Z      101675008
# 2020-02-24T14:15:02.444Z      101675008
# 2020-02-24T14:15:12.444Z      101675008
# 8['gateway1:9100' 'gateway2:9100']
# time                      mountpoint
# 2020-02-24T13:59:07.06Z   /boot               208601088
#                           /                 12048355328
#                           /run                468271104
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:59:17.061Z  /boot               208601088
#                           /                 12048355328
#                           /run                468267008
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:59:27.061Z  /boot               208601088
#                           /                 12048355328
#                           /run                468267008
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:59:37.06Z   /boot               208601088
#                           /                 12048355328
#                           /run                468267008
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# dtype: object
# mountpoint                          /      /boot       /run /run/lock  \
# time
# 2020-02-24T13:59:07.06Z   12048355328  208601088  468271104   5238784
# 2020-02-24T13:59:17.061Z  12048355328  208601088  468267008   5238784
# 2020-02-24T13:59:27.061Z  12048355328  208601088  468267008   5238784
# 2020-02-24T13:59:37.06Z   12048355328  208601088  468267008   5238784
# 2020-02-24T13:59:47.06Z   12048355328  208601088  468267008   5238784
#
# mountpoint               /run/user/1000
# time
# 2020-02-24T13:59:07.06Z       101675008
# 2020-02-24T13:59:17.061Z      101675008
# 2020-02-24T13:59:27.061Z      101675008
# 2020-02-24T13:59:37.06Z       101675008
# 2020-02-24T13:59:47.06Z       101675008
# time                      mountpoint
# 2020-02-24T13:59:12.444Z  /boot               208601088
#                           /                 12046954496
#                           /run                461910016
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:59:22.444Z  /boot               208601088
#                           /                 12046950400
#                           /run                461905920
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:59:32.444Z  /boot               208601088
#                           /                 12046950400
#                           /run                461905920
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:59:42.444Z  /boot               208601088
#                           /                 12046950400
#                           /run                461905920
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# dtype: object
# mountpoint                          /      /boot       /run /run/lock  \
# time
# 2020-02-24T13:59:12.444Z  12046954496  208601088  461910016   5238784
# 2020-02-24T13:59:22.444Z  12046950400  208601088  461905920   5238784
# 2020-02-24T13:59:32.444Z  12046950400  208601088  461905920   5238784
# 2020-02-24T13:59:42.444Z  12046950400  208601088  461905920   5238784
# 2020-02-24T13:59:52.444Z  12046950400  208601088  461905920   5238784
#
# mountpoint               /run/user/1000
# time
# 2020-02-24T13:59:12.444Z      101675008
# 2020-02-24T13:59:22.444Z      101675008
# 2020-02-24T13:59:32.444Z      101675008
# 2020-02-24T13:59:42.444Z      101675008
# 2020-02-24T13:59:52.444Z      101675008
# 9['gateway1:9100' 'gateway2:9100']
# time                     mountpoint
# 2020-02-24T13:13:47.06Z  /boot               208601088
#                          /                 12047462400
#                          /run                474750976
#                          /run/lock             5238784
#                          /run/user/1000      101675008
# 2020-02-24T13:13:57.06Z  /boot               208601088
#                          /                 12047462400
#                          /run                474746880
#                          /run/lock             5238784
#                          /run/user/1000      101675008
# 2020-02-24T13:14:07.06Z  /boot               208601088
#                          /                 12047462400
#                          /run                474746880
#                          /run/lock             5238784
#                          /run/user/1000      101675008
# 2020-02-24T13:14:17.06Z  /boot               208601088
#                          /                 12047462400
#                          /run                474746880
#                          /run/lock             5238784
#                          /run/user/1000      101675008
# dtype: object
# mountpoint                         /      /boot       /run /run/lock  \
# time
# 2020-02-24T13
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:21:37.061Z  /boot               208601088
#                           /                 12047364096
#                           /run                474726400
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:21:47.06Z   /boot               208601088
#                           /                 12047364096
#                           /run                474726400
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:21:57.061Z  /boot               208601088
#                           /                 12047364096
#                           /run                474726400
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# dtype: object
# mountpoint                          /      /boot       /run /run/lock  \
# time
# 2020-02-24T13:21:27.06Z   12047364096  208601088  474730496   5238784
# 2020-02-24T13:21:37.061Z  12047364096  208601088  474726400   5238784
# 2020-02-24T13:21:47.06Z   12047364096  208601088  474726400   5238784
# 2020-02-24T13:21:57.061Z  12047364096  208601088  474726400   5238784
# 2020-02-24T13:22:07.061Z  12047364096  208601088  474726400   5238784
#
# mountpoint               /run/user/1000
# time
# 2020-02-24T13:21:27.06Z       101675008
# 2020-02-24T13:21:37.061Z      101675008
# 2020-02-24T13:21:47.06Z       101675008
# 2020-02-24T13:21:57.061Z      101675008
# 2020-02-24T13:22:07.061Z      101675008
# 13['gateway1:9100' 'gateway2:9100']
# time                     mountpoint
# 2020-02-24T13:51:37.06Z  /boot               208601088
#                          /                 12048449536
#                          /run                468291584
#                          /run/lock             5238784
#                          /run/user/1000      101675008
# 2020-02-24T13:51:47.06Z  /boot               208601088
#                          /                 12048449536
#                          /run                468287488
#                          /run/lock             5238784
#                          /run/user/1000      101675008
# 2020-02-24T13:51:57.06Z  /boot               208601088
#                          /                 12048449536
#                          /run                468287488
#                          /run/lock             5238784
#                          /run/user/1000      101675008
# 2020-02-24T13:52:07.06Z  /boot               208601088
#                          /                 12048449536
#                          /run                468287488
#                          /run/lock             5238784
#                          /run/user/1000      101675008
# dtype: object
# mountpoint                         /      /boot       /run /run/lock  \
# time
# 2020-02-24T13:51:37.06Z  12048449536  208601088  468291584   5238784
# 2020-02-24T13:51:47.06Z  12048449536  208601088  468287488   5238784
# 2020-02-24T13:51:57.06Z  12048449536  208601088  468287488   5238784
# 2020-02-24T13:52:07.06Z  12048449536  208601088  468287488   5238784
# 2020-02-24T13:52:17.06Z  12048449536  208601088  468287488   5238784
#
# mountpoint              /run/user/1000
# time
# 2020-02-24T13:51:37.06Z      101675008
# 2020-02-24T13:51:47.06Z      101675008
# 2020-02-24T13:51:57.06Z      101675008
# 2020-02-24T13:52:07.06Z      101675008
# 2020-02-24T13:52:17.06Z      101675008
# time                      mountpoint
# 2020-02-24T13:51:42.444Z  /boot               208601088
#                           /                 12047044608
#                           /run                461930496
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:51:52.444Z  /boot               208601088
#                           /                 12047036416
#                           /run                461926400
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:52:02.444Z  /boot               208601088
#                           /                 12047036416
#                           /run                461926400
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# 2020-02-24T13:52:12.444Z  /boot               208601088
#                           /                 12047036416
#                           /run                461926400
#                           /run/lock             5238784
#                           /run/user/1000      101675008
# dtype: object
# mountpoint                          /      /boot       /run /run/lock  \
# time
# 2020-02-24T13:51:42.444Z  12047044608  208601088  461930496   5238784
# 2020-02-24T13:51:52.444Z  12047036416  208601088  461926400   5238784
# 2020-02-24T13:52:02.444Z  12047036416  208601088  461926400   5238784
# 2020-02-24T13:52:12.444Z  12047036416  208601088  461926400   5238784
# 2020-02-24T13:52:22.444Z  12047036416  208601088  461926400   5238784
#
# mountpoint               /run/user/1000
# time
# 2020-02-24T13:51:42.444Z      101675008
# 2020-02-24T13:51:52.444Z      101675008
# 2020-02-24T13:52:02.444Z      101675008
# 2020-02-24T13:52:12.444Z      101675008
# 2020-02-24T13:52:22.444Z      101675008
